# %%
import pandas as pd
import os
from matplotlib import pylab as plt

os.chdir('C:/Users/joe.solway/Documents/GitHub/GeneralAssembly/')   # Change current working directory
df = pd.read_csv('income.csv') #csv import uses comma as delimeter
#df.head(20)
df.tail(20)


fig = plt.figure(figsize=(10, 3))
fig.suptitle('Distribution of Income Levels')
ax1 = fig.add_subplot(131)
ax1.scatter(df['value'], df['count'])
ax2 = fig.add_subplot(132)
ax2.scatter(df['value'], df['mean'])
ax3 = fig.add_subplot(133)
ax3.scatter(df['value'], df['prop'])

print fig
# Out:
# Figure(800x240)

# %%
df.tail(20)
df
# Out:
#     Unnamed: 0   value  count    mean      prop
# 0            1       0   2588     298  0.022085
# 1            2    2500    971    3792  0.008286
# 2            3    5000   1677    6261  0.014311
# 3            4    7500   3141    8705  0.026804
# 4            5   10000   3684   11223  0.031438
# 5            6   12500   3163   13687  0.026992
# 6            7   15000   3600   16074  0.030721
# 7            8   17500   3116   18662  0.026591
# 8            9   20000   3967   21064  0.033853
# 9           10   22500   3117   23698  0.026599
# 10          11   25000   3620   26003  0.030892
# 11          12   27500   2808   28637  0.023963
# 12          13   30000   3736   30982  0.031882
# 13          14   32500   2569   33706  0.021923
# 14          15   35000   3517   35966  0.030013
# 15          16   37500   2483   38664  0.021189
# 16          17   40000   3343   40970  0.028528
# 17          18   42500   2250   43635  0.019201
# 18          19   45000   2698   45964  0.023024
# ...
